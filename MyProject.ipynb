# %% [markdown]
# # Day 1

# %% [markdown]
# ## CarDATA

# %% [markdown]
# #### Data source : kaggle

# %% [markdown]
# ### Project Aim
#
# 1) How does the manufacturing year affect the selling price of a car?
# 2) Which fuel type (petrol, diesel, LPG, etc.) has higher resale value?
# 3) Do automatic cars have higher prices than manual cars?
# 4) Does seller type (Individual vs Dealer) influence the selling price?
# 5) How does the number of previous owners affect the car price?
# 6) Is there a relationship between mileage and selling price?
# 7) Does engine capacity (cc) impact the selling price?
# 8) How do max power and engine cc affect the price of a car?
# 9) Does the number of seats influence the selling price?
# 10) What is the depreciation trend of cars over time?

# %% [markdown]
# - importing library

# %%
import pandas as pd

# %% [markdown]
# - loading data

# %%
df = pd.read_csv("car.csv")
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# - inspect data

# %%
df.sample()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 5164  Mitsubishi Lancer 2.0 GLd  2008         165000     120000  Diesel
#
#      seller_type transmission        owner    mileage   engine max_power  \
# 5164  Individual       Manual  Third Owner  14.8 kmpl  1998 CC    68 bhp
#
#                      torque  seats
# 5164  12.5@ 3,000(kgm@ rpm)    5.0

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.tail()
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#       max_power                     torque  seats
# 8123  82.85 bhp           113.7Nm@ 4000rpm    5.0
# ...

# %% [markdown]
# - checking data type

# %%
df.dtypes
# Out:
# name                 str
# year               int64
# selling_price      int64
# km_driven          int64
# fuel                 str
# seller_type          str
# transmission         str
# owner                str
# mileage              str
# engine               str
# max_power            str
# torque               str
# seats            float64
# dtype: object

# %% [markdown]
# - Display column names

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='str')

# %% [markdown]
# - Display number of rows and columns

# %%
df.shape
# Out:
# (8128, 13)

# %% [markdown]
# - Technical summary

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   str
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   str
#  5   seller_type    8128 non-null   str
#  6   transmission   8128 non-null   str
#  7   owner          8128 non-null   str
#  8   mileage        7907 non-null   str
#  9   engine         7907 non-null   str
#  10  max_power      7913 non-null   str
#  11  torque         7906 non-null   str
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), str(9)
# memory usage: 825.6 KB

# %% [markdown]
# ## ANALYSIS FROM ABOVE

# %% [markdown]
# ## Missing values
#
# - 221 mileage values are missing and also 15 mileges are zero(its not possible at all)
# - 221 engine values are missing
# - 215 max_power values are missing
# - 222 torque values are missing
# - 221 seats values are missing

# %% [markdown]
# ## Errors in datatype
#
# - mileage is not a string but float (A character kmpl is added with number)
# - engine is not a string but float(A character CC is added with number)
# - max_power is not a string but float(A character bhp is added with number)
# - torque is not a string but float(Characters like Nm and rpm is added with number)
# - seats is not a float but integer(decimal is added with number)
# - therefor total number of floats is 4,integer is 4 and string is 5.

# %% [markdown]
# ## Selecting columns

# %% [markdown]
# - single column

# %%
df['engine']
# Out:
# 0       1248 CC
# 1       1498 CC
# 2       1497 CC
# 3       1396 CC
# 4       1298 CC
#          ...
# 8123    1197 CC
# 8124    1493 CC
# 8125    1248 CC
# 8126    1396 CC
# 8127    1396 CC
# Name: engine, Length: 8128, dtype: str

# %% [markdown]
# - Multiple column

# %%
df[['engine','torque']]
# Out:
#        engine                     torque
# 0     1248 CC             190Nm@ 2000rpm
# 1     1498 CC        250Nm@ 1500-2500rpm
# 2     1497 CC      12.7@ 2,700(kgm@ rpm)
# 3     1396 CC   22.4 kgm at 1750-2750rpm
# 4     1298 CC      11.5@ 4,500(kgm@ rpm)
# ...       ...                        ...
# 8123  1197 CC           113.7Nm@ 4000rpm
# 8124  1493 CC  24@ 1,900-2,750(kgm@ rpm)
# 8125  1248 CC             190Nm@ 2000rpm
# 8126  1396 CC        140Nm@ 1800-3000rpm
# 8127  1396 CC        140Nm@ 1800-3000rpm
#
# [8128 rows x 2 columns]

# %% [markdown]
# - Make it as a new column

# %%
new = df[['engine','torque']]
new
# Out:
#        engine                     torque
# 0     1248 CC             190Nm@ 2000rpm
# 1     1498 CC        250Nm@ 1500-2500rpm
# 2     1497 CC      12.7@ 2,700(kgm@ rpm)
# 3     1396 CC   22.4 kgm at 1750-2750rpm
# 4     1298 CC      11.5@ 4,500(kgm@ rpm)
# ...       ...                        ...
# 8123  1197 CC           113.7Nm@ 4000rpm
# 8124  1493 CC  24@ 1,900-2,750(kgm@ rpm)
# 8125  1248 CC             190Nm@ 2000rpm
# 8126  1396 CC        140Nm@ 1800-3000rpm
# 8127  1396 CC        140Nm@ 1800-3000rpm
#
# [8128 rows x 2 columns]

# %% [markdown]
# # Selecting rows

# %% [markdown]
# - Single rows

# %%
df.iloc[670]
# Out:
# name             Maruti Alto LXi
# year                        2012
# selling_price             215000
# km_driven                  90000
# fuel                      Petrol
# seller_type           Individual
# transmission              Manual
# owner                Third Owner
# mileage                19.7 kmpl
# engine                    796 CC
# max_power               46.3 bhp
# torque             62Nm@ 3000rpm
# seats                        5.0
# Name: 670, dtype: object

# %% [markdown]
# - Selecting a Portion

# %%
df.iloc[1000:2000]
# Out:
#                                            name  year  selling_price  \
# 1000                           Renault KWID RXT  2016         330000
# 1001        Mahindra Bolero 2011-2019 EX NON AC  2014         480000
# 1002  Maruti S-Cross 2017-2020 Zeta DDiS 200 SH  2018         950000
# 1003        Hyundai Verna Transform SX VGT CRDi  2011         300000
# 1004                  Hyundai Verna Xi (Petrol)  2006         170000
# ...                                         ...   ...            ...
# 1995              Maruti Vitara Brezza ZDi Plus  2016         839000
# 1996        Volkswagen Polo 1.2 MPI Comfortline  2019         635000
# 1997       Mahindra Scorpio VLX 2WD AIRBAG BSIV  2014         550000
# 1998              Mahindra Logan Diesel 1.5 DLE  2011         180000
# 1999                        Honda City i DTEC E  2015         650000
#
#       km_driven    fuel seller_type transmission                 owner  \
# ...

# %% [markdown]
# - Selecting a Particular feature from a row

# %%
df.loc[710,'owner']
# Out:
# 'Second Owner'

# %% [markdown]
# # Filter the data

# %% [markdown]
# - Seating capacity above 5

# %%
df[df['seats']>5.0]
# Out:
#                                               name  year  selling_price  \
# 16                          Maruti Ertiga SHVS VDI  2016         778000
# 27               Chevrolet Enjoy TCDi LTZ 7 Seater  2013         300000
# 29                     Maruti Omni E MPI STD BS IV  2018         254999
# 39                    Tata Safari DICOR 2.2 LX 4x2  2011         425000
# 47                          Toyota Fortuner 4x4 MT  2014        1500000
# ...                                            ...   ...            ...
# 8077                     Toyota Innova 2.5 E 7 STR  2009         550000
# 8080              Tata New Safari DICOR 2.2 EX 4x2  2010         300000
# 8083                          Chevrolet Captiva LT  2008         300000
# 8099                        Mahindra XUV500 W8 2WD  2013         750000
# 8113  Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV  2010         425000
#
#       km_driven    fuel seller_type transmission         owner     mileage  \
# ...

# %% [markdown]
# - Seat Capacity of 7

# %%
df[df['seats']== 7.0]
# Out:
#                                              name  year  selling_price  \
# 16                         Maruti Ertiga SHVS VDI  2016         778000
# 27              Chevrolet Enjoy TCDi LTZ 7 Seater  2013         300000
# 39                   Tata Safari DICOR 2.2 LX 4x2  2011         425000
# 47                         Toyota Fortuner 4x4 MT  2014        1500000
# 48    Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2013         700000
# ...                                           ...   ...            ...
# 8071          Toyota Innova 2.5 V Diesel 7-seater  2010         425000
# 8077                    Toyota Innova 2.5 E 7 STR  2009         550000
# 8080             Tata New Safari DICOR 2.2 EX 4x2  2010         300000
# 8083                         Chevrolet Captiva LT  2008         300000
# 8099                       Mahindra XUV500 W8 2WD  2013         750000
#
#       km_driven    fuel seller_type transmission         owner     mileage  \
# ...

# %% [markdown]
# - Petrol vehicle

# %%
df[df['fuel']=='Petrol']
# Out:
#                                    name  year  selling_price  km_driven  \
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 11                        Maruti Zen LX  2005          92000     100000
# ...                                 ...   ...            ...        ...
# 8118                  Hyundai i20 Magna  2013         380000      25000
# 8119        Maruti Wagon R LXI Optional  2017         360000      80000
# 8120            Hyundai Santro Xing GLS  2008         120000     191000
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8123                  Hyundai i20 Magna  2013         320000     110000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %% [markdown]
# - Diesel Vehicle

# %%
df[df['fuel']=='Diesel']
# Out:
#                                       name  year  selling_price  km_driven  \
# 0                   Maruti Swift Dzire VDI  2014         450000     145500
# 1             Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 3                Hyundai i20 Sportz Diesel  2010         225000     127000
# 8                         Toyota Etios VXD  2011         350000      90000
# 9     Ford Figo Diesel Celebration Edition  2013         200000     169000
# ...                                    ...   ...            ...        ...
# 8122            Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8124                 Hyundai Verna CRDi SX  2007         135000     119000
# 8125                Maruti Swift Dzire ZDi  2009         382000     120000
# 8126                       Tata Indigo CR4  2013         290000      25000
# 8127                       Tata Indigo CR4  2013         290000      25000
#
# ...

# %% [markdown]
# - Manual Transmitting Vehicles

# %%
df[df['transmission']=='Manual']
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# ## Filtering with multiple conditions

# %%
df[(df['fuel']=='Diesel')&(df['owner']=='First Owner')]
# Out:
#                                               name  year  selling_price  \
# 0                           Maruti Swift Dzire VDI  2014         450000
# 3                        Hyundai i20 Sportz Diesel  2010         225000
# 8                                 Toyota Etios VXD  2011         350000
# 9             Ford Figo Diesel Celebration Edition  2013         200000
# 19             Hyundai i20 2015-2017 Asta 1.4 CRDi  2016         680000
# ...                                            ...   ...            ...
# 8113  Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV  2010         425000
# 8117                        Maruti Swift Dzire VDI  2015         625000
# 8125                        Maruti Swift Dzire ZDi  2009         382000
# 8126                               Tata Indigo CR4  2013         290000
# 8127                               Tata Indigo CR4  2013         290000
#
#       km_driven    fuel seller_type transmission        owner     mileage  \
# ...

# %% [markdown]
# ## Rename column

# %%
df.rename(columns={"selling_price":"asking_price","year":"model"},inplace=True)
df
# Out:
#                               name  model  asking_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI   2014        450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition   2014        370000     120000  Diesel
# 2         Honda City 2017-2020 EXi   2006        158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel   2010        225000     127000  Diesel
# 4           Maruti Swift VXI BSIII   2007        130000     120000  Petrol
# ...                            ...    ...           ...        ...     ...
# 8123             Hyundai i20 Magna   2013        320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX   2007        135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi   2009        382000     120000  Diesel
# 8126               Tata Indigo CR4   2013        290000      25000  Diesel
# 8127               Tata Indigo CR4   2013        290000      25000  Diesel
#
# ...

# %% [markdown]
# ## To find Unique counts

# %% [markdown]
# - Number of Manual and Automatic transmission vehicles

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual       7078
# Automatic    1050
# Name: count, dtype: int64

# %% [markdown]
# - Number of single and multiple ownership vehicles

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %% [markdown]
# - Vehicles manfacturing years

# %%
df['model'].value_counts()
# Out:
# model
# 2017    1018
# 2016     859
# 2018     807
# 2015     776
# 2013     670
# 2012     651
# 2014     621
# 2011     592
# 2019     583
# 2010     394
# 2009     246
# 2008     214
# 2007     183
# 2006     124
# 2005      97
# 2020      74
# 2004      62
# 2003      49
# 2002      27
# 2000      22
# 1999      18
# 1997      11
# 2001      10
# 1998      10
# 1996       3
# 1994       3
# 1995       2
# 1983       1
# 1991       1
# Name: count, dtype: int64

# %% [markdown]
# # Day 2

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# - Remove text units and convert to numbers

# %% [markdown]
# > Changing datatypes

# %%
df['engine'] = pd.to_numeric(
    df['engine']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None),
    errors='coerce'
)
df
# Out:
#                               name  model  asking_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI   2014        450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition   2014        370000     120000  Diesel
# 2         Honda City 2017-2020 EXi   2006        158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel   2010        225000     127000  Diesel
# 4           Maruti Swift VXI BSIII   2007        130000     120000  Petrol
# ...                            ...    ...           ...        ...     ...
# 8123             Hyundai i20 Magna   2013        320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX   2007        135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi   2009        382000     120000  Diesel
# 8126               Tata Indigo CR4   2013        290000      25000  Diesel
# 8127               Tata Indigo CR4   2013        290000      25000  Diesel
#
# ...

# %%
df['mileage'] = pd.to_numeric(
    df['mileage']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None)
)
df
# Out:
#                               name  model  asking_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI   2014        450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition   2014        370000     120000  Diesel
# 2         Honda City 2017-2020 EXi   2006        158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel   2010        225000     127000  Diesel
# 4           Maruti Swift VXI BSIII   2007        130000     120000  Petrol
# ...                            ...    ...           ...        ...     ...
# 8123             Hyundai i20 Magna   2013        320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX   2007        135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi   2009        382000     120000  Diesel
# 8126               Tata Indigo CR4   2013        290000      25000  Diesel
# 8127               Tata Indigo CR4   2013        290000      25000  Diesel
#
# ...

# %%
df['max_power'] = pd.to_numeric(
    df['max_power']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None)
)
df
# Out:
#                               name  model  asking_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI   2014        450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition   2014        370000     120000  Diesel
# 2         Honda City 2017-2020 EXi   2006        158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel   2010        225000     127000  Diesel
# 4           Maruti Swift VXI BSIII   2007        130000     120000  Petrol
# ...                            ...    ...           ...        ...     ...
# 8123             Hyundai i20 Magna   2013        320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX   2007        135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi   2009        382000     120000  Diesel
# 8126               Tata Indigo CR4   2013        290000      25000  Diesel
# 8127               Tata Indigo CR4   2013        290000      25000  Diesel
#
# ...

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: count, dtype: int64

# %% [markdown]
# # Dropping column

# %% [markdown]
# - Drop torque column because it has no job to done in this data set and the values are not given properly.

# %%
df.drop(columns=['torque'],inplace=True)

# %%
df
# Out:
#                               name  model  asking_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI   2014        450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition   2014        370000     120000  Diesel
# 2         Honda City 2017-2020 EXi   2006        158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel   2010        225000     127000  Diesel
# 4           Maruti Swift VXI BSIII   2007        130000     120000  Petrol
# ...                            ...    ...           ...        ...     ...
# 8123             Hyundai i20 Magna   2013        320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX   2007        135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi   2009        382000     120000  Diesel
# 8126               Tata Indigo CR4   2013        290000      25000  Diesel
# 8127               Tata Indigo CR4   2013        290000      25000  Diesel
#
# ...

# %% [markdown]
# # Day 3

# %% [markdown]
# ## Handling missing values

# %%
df.isnull().sum()
# Out:
# name              0
# model             0
# asking_price      0
# km_driven         0
# fuel              0
# seller_type       0
# transmission      0
# owner             0
# mileage         221
# engine          221
# max_power       216
# seats           221
# dtype: int64

# %%
df.dropna()
# Out:
#                               name  model  asking_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI   2014        450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition   2014        370000     120000  Diesel
# 2         Honda City 2017-2020 EXi   2006        158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel   2010        225000     127000  Diesel
# 4           Maruti Swift VXI BSIII   2007        130000     120000  Petrol
# ...                            ...    ...           ...        ...     ...
# 8123             Hyundai i20 Magna   2013        320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX   2007        135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi   2009        382000     120000  Diesel
# 8126               Tata Indigo CR4   2013        290000      25000  Diesel
# 8127               Tata Indigo CR4   2013        290000      25000  Diesel
#
# ...

# %% [markdown]
# - DECISION
#
# > Through dropping rows,222 vehicles is dropping.It will be a huge loss for company.we will fix it through some methods

# %% [markdown]
# ## Filling missing values

# %% [markdown]
# 1.Engine rows filling through median method

# %%
df['engine']=df['engine'].fillna(df['engine'].median())

# %% [markdown]
# 2.Mileage rows filling through median

# %%
df['mileage']=df['mileage'].fillna(df['mileage'].median())

# %% [markdown]
# 3. Max power rows filling through median method

# %%
df['max_power']=df['max_power'].fillna(df['max_power'].median())

# %% [markdown]
# 4.seats rows filling though making 5

# %%
df['seats']=df['seats'].fillna(5)

# %%
df.dtypes
# Out:
# name                str
# model             int64
# asking_price      int64
# km_driven         int64
# fuel                str
# seller_type         str
# transmission        str
# owner               str
# mileage         float64
# engine          float64
# max_power       float64
# seats           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8128 non-null   str
#  1   model         8128 non-null   int64
#  2   asking_price  8128 non-null   int64
#  3   km_driven     8128 non-null   int64
#  4   fuel          8128 non-null   str
#  5   seller_type   8128 non-null   str
#  6   transmission  8128 non-null   str
#  7   owner         8128 non-null   str
#  8   mileage       8128 non-null   float64
#  9   engine        8128 non-null   float64
#  10  max_power     8128 non-null   float64
#  11  seats         8128 non-null   float64
# dtypes: float64(4), int64(3), str(5)
# memory usage: 762.1 KB

# %%
df.isnull().sum()
# Out:
# name            0
# model           0
# asking_price    0
# km_driven       0
# fuel            0
# seller_type     0
# transmission    0
# owner           0
# mileage         0
# engine          0
# max_power       0
# seats           0
# dtype: int64

# %% [markdown]
# ### Changing data type of seats

# %%
df['seats']=df['seats'].astype(int)

# %%
df.dtypes
# Out:
# name                str
# model             int64
# asking_price      int64
# km_driven         int64
# fuel                str
# seller_type         str
# transmission        str
# owner               str
# mileage         float64
# engine          float64
# max_power       float64
# seats             int64
# dtype: object

# %%
df.shape
# Out:
# (8128, 12)

# %% [markdown]
# # Day 4

# %% [markdown]
# #  Handling duplicates

# %%
df.duplicated().sum()
# 1202 duplicates
# Out:
# np.int64(1202)

# %%
print('before:',df.shape)
df= df.drop_duplicates()
print('after:',df.shape)
# Out:
# before: (8128, 12)
# after: (6926, 12)

# %% [markdown]
# ##### This data has a problem there is exist 0 mileage vehicles zero mileage vehicles are not possible its possibly an data entry error

# %%
(df['mileage']==0).sum()
# Out:
# np.int64(15)

# %% [markdown]
# ##### This data have only errors in 15 column so we fix it through add data

# %%
df[df['mileage']==0].head(15)
# Out:
#                                                    name  model  asking_price  \
# 644   Tata Indica Vista Aura Safire Anniversary Edition   2009        135000
# 785                              Hyundai Santro Xing GL   2009        120000
# 1649                             Hyundai Santro Xing GL   2008        105000
# 1676                Mercedes-Benz M-Class ML 350 4Matic   2011       1700000
# 2137                    Land Rover Freelander 2 TD4 HSE   2013       1650000
# 2366                       Hyundai Santro Xing (Non-AC)   2010        110000
# 2725                       Hyundai Santro Xing (Non-AC)   2013        184000
# 5276                             Hyundai Santro Xing GL   2008        175000
# 5843                        Volkswagen Polo GT TSI BSIV   2014        574000
# 5846                        Volkswagen Polo GT TSI BSIV   2014        575000
# 5900                     Mahindra Bolero Pik-Up FB 1.7T   2020        679000
# ...

# %%
df.loc[[644,785,1649,1676,2137,2366,2725,5276,5843,5846,5900,6534,6629,6824,7337], 'mileage'] = \
[16.6,17.92,17.92,8.5,12.4,17.92,17.92,17.92,17.21,17.21,14.3,17.92,14.3,17.92,17.9]

# %%
df[df['mileage']==0].head(15)
# Out:
# Empty DataFrame
# Columns: [name, model, asking_price, km_driven, fuel, seller_type, transmission, owner, mileage, engine, max_power, seats]
# Index: []

# %% [markdown]
# # Checking wheather datas are cleaned

# %%
df.shape
# Out:
# (6926, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6926 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          6926 non-null   str
#  1   model         6926 non-null   int64
#  2   asking_price  6926 non-null   int64
#  3   km_driven     6926 non-null   int64
#  4   fuel          6926 non-null   str
#  5   seller_type   6926 non-null   str
#  6   transmission  6926 non-null   str
#  7   owner         6926 non-null   str
#  8   mileage       6926 non-null   float64
#  9   engine        6926 non-null   float64
#  10  max_power     6926 non-null   float64
#  11  seats         6926 non-null   int64
# dtypes: float64(3), int64(4), str(5)
# memory usage: 961.5 KB

# %%
df.columns
# Out:
# Index(['name', 'model', 'asking_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='str')

# %%
df.sample(10)
# Out:
#                                   name  model  asking_price  km_driven  \
# 7187       Maruti Zen Estilo LXI BSIII   2007         90000      70000
# 4726     Mahindra Bolero 2011-2019 SLX   2015        550000      30000
# 7375            Mahindra XUV500 W8 2WD   2014        850000      75000
# 627      Mahindra Bolero 2011-2019 SLX   2014        600000      50000
# 2781                  Mahindra Xylo H9   2015        575000     110000
# 4938         Hyundai i20 1.4 Asta (AT)   2009        360000      60000
# 3828               Honda City 1.5 V MT   2010        300000     100000
# 6634            Maruti Swift Dzire ZDI   2018        780000      30000
# 2972                   Maruti Alto LXi   2006         94500      44000
# 2842  Hyundai Verna CRDi 1.6 SX Option   2017        850000      35000
#
#         fuel seller_type transmission         owner  mileage  engine  \
# 7187  Petrol  Individual       Manual   First Owner    18.20   998.0
# ...

# %% [markdown]
# # Save the cleaned data to a new csv file

# %%
df.to_csv('cleaned_car.csv', index=False)

# %%
df_new = pd.read_csv('cleaned_car.csv')
df_new
# Out:
#                                    name  model  asking_price  km_driven  \
# 0                Maruti Swift Dzire VDI   2014        450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition   2014        370000     120000
# 2              Honda City 2017-2020 EXi   2006        158000     140000
# 3             Hyundai i20 Sportz Diesel   2010        225000     127000
# 4                Maruti Swift VXI BSIII   2007        130000     120000
# ...                                 ...    ...           ...        ...
# 6921  Maruti Wagon R VXI BS IV with ABS   2013        260000      50000
# 6922         Hyundai i20 Magna 1.4 CRDi   2014        475000      80000
# 6923                  Hyundai i20 Magna   2013        320000     110000
# 6924              Hyundai Verna CRDi SX   2007        135000     119000
# 6925             Maruti Swift Dzire ZDi   2009        382000     120000
#
#         fuel seller_type transmission                 owner  mileage  engine  \
# ...

# %% [markdown]
# # Summary Statistics

# %%
df.columns
# Out:
# Index(['name', 'model', 'asking_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='str')

# %% [markdown]
# ### Average(mean)

# %% [markdown]
# 1. Average Model

# %%
print("model - " ,df['model'].mean())
# Out:
# model -  2013.4203003176438

# %% [markdown]
# 2. Average asking price

# %%
print("asking_price - " ,df['asking_price'].mean())
# Out:
# asking_price -  517270.6784579844

# %% [markdown]
# 3. Average Engine cc

# %%
print("engine - " ,df['engine'].mean())
# Out:
# engine -  1425.3987871787467

# %% [markdown]
# 4.Average Power

# %%
print("max_power - " ,df['max_power'].mean())
# Out:
# max_power -  87.55658316488594

# %% [markdown]
# ### Median

# %% [markdown]
# 1. Model

# %%
print("model - " ,df['model'].median())
# Out:
# model -  2014.0

# %% [markdown]
# 2. Price

# %%
print("asking_price - " ,df['asking_price'].median())
# Out:
# asking_price -  400000.0

# %% [markdown]
# 3. Engine cc

# %%
print("engine - " ,df['engine'].median())
# Out:
# engine -  1248.0

# %% [markdown]
# 4. Power

# %%
print("max_power - " ,df['max_power'].median())
# Out:
# max_power -  81.86

# %% [markdown]
# ### Mode

# %%
df.columns
# Out:
# Index(['name', 'model', 'asking_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='str')

# %% [markdown]
# 1. Name

# %%
print("name - " ,df['name'].mode())
# Out:
# name -  0    Maruti Swift Dzire VDI
# Name: name, dtype: str

# %% [markdown]
# 2. Model

# %%
print("model - " ,df['model'].mode())
# Out:
# model -  0    2017
# Name: model, dtype: int64

# %% [markdown]
# All in one

# %%
df.select_dtypes(include='number').mode()
# Out:
#    model  asking_price  km_driven  mileage  engine  max_power  seats
# 0   2017        300000     120000     19.3  1248.0       74.0      5

# %% [markdown]
# ### Standard deviation

# %%
df.select_dtypes(include='number').std()
# Out:
# model                4.078286
# asking_price    519766.985985
# km_driven        58358.095175
# mileage              3.888449
# engine             487.026967
# max_power           31.310612
# seats                0.972171
# dtype: float64

# %% [markdown]
# # day 5

# %% [markdown]
# ## Numerical Data

# %%
df.describe()
# Out:
#              model  asking_price     km_driven      mileage       engine  \
# count  6926.000000  6.926000e+03  6.926000e+03  6926.000000  6926.000000
# mean   2013.420300  5.172707e+05  7.399568e+04    19.495554  1425.398787
# std       4.078286  5.197670e+05  5.835810e+04     3.888449   487.026967
# min    1983.000000  2.999900e+04  1.000000e+00     8.500000   624.000000
# 25%    2011.000000  2.500000e+05  4.000000e+04    16.960000  1197.000000
# 50%    2014.000000  4.000000e+05  7.000000e+04    19.300000  1248.000000
# 75%    2017.000000  6.335000e+05  1.000000e+05    22.320000  1498.000000
# max    2020.000000  1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power        seats
# count  6926.000000  6926.000000
# mean     87.556583     5.421600
# std      31.310612     0.972171
# min       0.000000     2.000000
# 25%      68.000000     5.000000
# 50%      81.860000     5.000000
# 75%      99.000000     5.000000
# max     400.000000    14.000000

# %% [markdown]
# #### Analysis from this data
# ##### 1. numericals

# %% [markdown]
# 1.Model
# - We have vehicles data from 1983 from 2020
# - 2014 is the median
# - most cars are relatively only(75 percentile is before 2017)
# >insights:Dataset is dominated by modern vehicles,which may influence higher resale values
#
# 2.Asking price
# - we have vehicles priced from 29,999 to 1cr
# - median is 4lakh
# - Average asking price is 5.17lakhs
# >insights:Large difference between average and median suggests price outliers/luxury cars.
# 3. KM driven
# - we have vehicles driven fron 1km to 23,360,457km
# - median is 7,0000 km
# - most cars fall between 40,000-1lakh
# >insight:most vehicle have moderate usage,while very high mileage cars may be outliers
#
# 4.Mileage
# - average mileage between is 19.49kmpl
# - median mileage is 19.3kmpl
# - mileage ranges from 8.5-42kmpl
# >insights:good fuel efficiency overall,Most cars have a typical mileage ranges of 17-22kmpl
#
# 5.Engine
# - Average engine size is 1425cc
# - median is 1248cc
# - Range is 624-3604cc
# >insight:Dataset mostly contains small to mid-sized passenger cars
# 6. Max Power
# - Average power is 87.56bhp
# - median is 81.86bhp
# - power range up to 400bhp
# >insights:High-power values indicate presence of premium/performance vehicles
#
# 7. Seats
# - Most vehicles have 5 seats
# - Average seating capacity is 5.4
# - Range is 2-14 seats
# >insights:Dataset is mainly composed of standard family cars

# %% [markdown]
# ## Categorical data

# %%
df.describe(include=object)
# Out:
# C:\Users\IC\AppData\Local\Temp\ipykernel_15000\3998025828.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include=object)
#                           name    fuel seller_type transmission        owner
# count                     6926    6926        6926         6926         6926
# unique                    2058       4           3            2            5
# top     Maruti Swift Dzire VDI  Diesel  Individual       Manual  First Owner
# freq                       118    3755        6218         6342         4242

# %% [markdown]
# #### Analysis from above data

# %% [markdown]
# 1. Name
# - There are 6926 entries but 2058 unique models → high diversity in car listings.
# - The most frequent model is “Maruti Swift Dzire VDI” with 118 occurrences → no single model dominates heavily.
# - Frequency of top model (118/6926 ≈ 1.7%) → very fragmented distribution.
# >insights:The dataset is highly diverse with no dominant model, meaning model-level trends may require grouping (e.g., by brand like Maruti, Hyundai) rather than analyzing individual models.
#
# 2. Fuel
# - Only 4 unique fuel types → low categorical complexity.
# - Diesel dominates with 3755 entries (~54%).
# - Remaining categories (Petrol, CNG, LPG) share the rest, likely unevenly.
# >Insight:The dataset is skewed toward diesel vehicles, suggesting either market preference (older datasets often favor diesel) or sampling bias—important when building predictive models.

# %% [markdown]
# 3.Seller_type
# - 3 unique seller types → likely Individual, Dealer, Trustmark Dealer.
# - Individuals dominate heavily (6218/6926 ≈ 90%).
# - Dealers and others form a small minority.
# >Insight:Most listings come from individual sellers, so pricing trends may reflect non-professional pricing behavior, which can increase variability.
#
# 4.Transmission
# - Only 2 categories → Manual and Automatic.
# - Manual cars dominate (6342/6926 ≈ 92%).
# - Automatics are very underrepresented.
# >Insight:The dataset is strongly biased toward manual cars, which could distort any model predicting price or demand for automatic vehicles.
#
# 5.Owner
# - 5 unique ownership categories (e.g., First Owner, Second Owner, etc.).
# - First Owner dominates (4242/6926 ≈ 61%).
# - Higher-order ownership categories are progressively less frequent.
# >Insight:Most cars are first-owner vehicles, which typically have higher resale value—this variable will likely be important for price prediction.

# %% [markdown]
# # Day 6

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate analysis

# %% [markdown]
# ## Histogram
# - Distribution of numerical data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(5,3))
sns.histplot(data=df_new,x="model")
plt.title("Distribution of vehicle model years")
plt.show()

# %% [markdown]
# ### Analyses from above histplot

# %% [markdown]
# 1. Median model year is arround 2014
# 2. Skewness is on left side→More spread on older vehicles
# 3. Some outliers is spotted
#  - low outliers on left side its starts arround 1983 to 2001
#   > representing data contains lower model vehicles
#  - high outliers on right side its not vissible
#   > Newest vehicles not contains in this dataset

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=df_new,x="asking_price",hue='transmission')
plt.title("Distribution of vehicle asking price")
plt.show()

# %% [markdown]
# ### Analyses from above histplot

# %% [markdown]
# 1. Median asking price is concentrated in lower price
# 2. Skewness is on right side →More spread on higher priced vehicles
# 3. Some outliers are spotted
#    - low outliers on left side is not vissible.because few or abscent of less extreme underpriced vehicles
#    - high outliers on right side.its indicating premium/luxury vehicle

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=df_new,x="km_driven")
plt.title("Distribution of vehicle kilometer driven")
plt.show()

# %% [markdown]
# ### Analyses from above histplot

# %% [markdown]
# 1. Median kilometers driven is concentrated in lower mileage
# 2. Skewness is on right side → More spread on higher mileage vehicles
#
# 3. Some outliers are spotted
#   - low outliers on left side is not visible because few or absent of less extreme low mileage vehicles
#   - high outliers on right side indicating unusually high mileage vehicles

# %%
df_new['km_driven'].median()
# Out:
# np.float64(70000.0)

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=df_new,x="mileage")
plt.title("Distribution of vehicle mileage")
plt.show()

# %% [markdown]
# ### Analyses from above histplot

# %% [markdown]
# 1. The median mileage is around 20
# 2. The right whisker is longer and there are more points on the right side
#  Some vehicles have unusually high mileage
#
# 3. Some outliers is spotted
#       - low outliers on left side spotted
#       - some high outliers is spotted in right side
# > Interpretation:
# - Low outlier>possibly vehicles with lower mileage
# - High outliers>vehicles with exceptionally high mileage

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=df_new,x="engine")
plt.title("Distribution of vehicle engine in cc")
plt.show()

# %% [markdown]
# ### Analyses from above histplot

# %% [markdown]
# 1. The median engine is around ~1300–1400 cc
# 2. skewness is on rightside
#  → This indicates a strong right (positive) skew
# 3. Some outliers is spotted
#       - low outliers on left side its start from arround 700cc go upto 800cc
#          >Likely:
#             Small/compact cars
#       - high outliers on right side its start from arround 2000 cc and go up to 3600+ cc
#          >Likely:
#          SUVs,Luxury cars and performance vehicles

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=df_new,x="max_power")
plt.title("Distribution of vehicle max power")
plt.show()

# %% [markdown]
# ### Analyses from above histplot

# %% [markdown]
# 1. Median max power is around ~90bhp–100bhp
# 2. Skewness is on rightside→A small number of vehicles have very high power
#
# 3. Some outlier is spotted
# - low outliers on left side its start from arround 10bhp–20bhp
#      >its possibly very low power powers or possible data entry issue
# - high outliers on right side its start from arround 140bhp and go up to 400bhp
#  >its possibly an high performance,sport and luxury cars

# %% [markdown]
# ### kde plot

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=df_new,x="seats",bins=20,color="blue",kde=True)
plt.title("Distribution of vehicle seating capacity")
plt.xlabel("seats")
plt.ylabel("count")
plt.show()

# %% [markdown]
# ## Analysis from above
#
# - The distribution is heavily unimodal, with 5-seater vehicles being the overwhelming standard. This reflects a market focused on personal and small family use.
#
# - A smaller but distinct peak exists for 7-seater vehicles, highlighting a steady secondary demand for larger family or commercial utility vehicles.
#
# - Vehicles with 2, 4, or 8+ seats are statistical outliers. Capacity beyond 8 seats is virtually non-existent in this dataset, indicating a very specialized or rare vehicle category.

# %% [markdown]
# ## Box plot

# %% [markdown]
# #### i) Mileage

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df_new,x="mileage")
plt.title("Distribution of vehicle mileage")
plt.show()

# %% [markdown]
# ### Analyses from above box plot

# %% [markdown]
# 1. The median mileage is around 20
# 2. The right whisker is longer and there are more points on the right side
#  Some vehicles have unusually high mileage
#
# 3. Some outliers is spotted
#       - low outliers on left side spotted
#       - some high outliers is spotted in right side
# > Interpretation:
# - Low outlier →Its possibly an very low mileage vehicles
# - High outliers →vehicles with exceptionally high mileage

# %% [markdown]
# ####  ii)Engine

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df_new,x="engine")
plt.title("Distribution of vehicle engine in cc")
plt.show()

# %% [markdown]
# ### Analyses from above box plot
# 1. The median engine is around ~1300–1400 cc
# 2. skewness is on rightside
#  → This indicates a strong right (positive) skew
# 3. Some outliers is spotted
#       - low outliers on left side its start from arround 700cc go upto 800cc
#          >Likely:
#             Small/compact cars
#       - high outliers on right side its start from arround 2000 cc and go up to 3600+ cc
#          >Likely:
#          SUVs,Luxury cars and performance vehicles

# %% [markdown]
# #### iii)max_power

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df_new,x="max_power")
plt.title("Distribution of vehicle max power")
plt.show()

# %% [markdown]
# ### Analyses from above box plot

# %% [markdown]
# 1. Median max power is around ~90bhp–100bhp
# 2. Skewness is on rightside→A small number of vehicles have very high power
#
# 3. Some outlier is spotted
# - low outliers on left side its start from arround 10bhp–20bhp
#      >its possibly very low power powers or possible data entry issue
# - high outliers on right side its start from arround 140bhp and go up to 400bhp
#  >its possibly an high performance,sport and luxury cars

# %% [markdown]
# #### iv)Model year

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df_new,x="model")
plt.title("Distribution of vehicle model years")
plt.show()

# %% [markdown]
# ### Analyses from above box plot

# %% [markdown]
# 1. Median model year is arround 2014
# 2. Skewness is on left side→More spread on older vehicles
# 3. Some outliers is spotted
#  - low outliers on left side its starts arround 1983 to 2001
#   > representing data contains lower model vehicles
#  - high outliers on right side its not vissible
#   > Newest vehicles not contains in this dataset

# %% [markdown]
# ### v)Price

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df_new,x="asking_price")
plt.title("Distribution of vehicle asking price")
plt.show()

# %% [markdown]
# ### Analyses from above box plot

# %% [markdown]
# 1. Median asking price is concentrated in lower price
# 2. Skewness is on right side →More spread on higher priced vehicles
# 3. Some outliers are spotted
#    - low outliers on left side is not vissible.because few or abscent of less extreme underpriced vehicles
#    - high outliers on right side.its indicating premium/luxury vehicle

# %% [markdown]
# ### vi)km driven

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df_new,x="km_driven")
plt.title("Distribution of vehicle kilometer driven")
plt.xlabel("kilometer driven")
plt.ylabel("count")
plt.show()

# %% [markdown]
# ### Analyses from above box plot

# %% [markdown]
# 1. Median kilometers driven is concentrated in lower range,showing many vehicles have moderate usage.
# 2. Skewness is on right side → A very few vehicles have very high kilometer driven compared to the majority
#
# 3. Some outliers are spotted
#   - low outliers on left side is not visible because few or absent of less extremely low kilometer vehicles
#   - high outliers on right side indicating unusually extreme high kilometer drivened vehicles,arround 1.5m and 2.3m km

# %% [markdown]
# ## Countplot

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=df_new,x='transmission')
plt.title("Transmission of vehicles")
plt.xlabel("Transmission types")
plt.ylabel("count")
plt.show()

# %% [markdown]
# ### Analysis from above
#
# - Number of manual vehicles is more than automatic vehicls and also it has huge differece
# - Automatic vehicles account for a very small portion of the dataset, appearing to be around 600 to 700 vehicles.This suggests that for every 1 automatic car in this data, there are roughly 10 manual cars.

# %% [markdown]
# ## Pie chart

# %%
df_new['owner'].value_counts().plot.pie(
    autopct='%1.1f%%',
    figsize=(10,10),
    title='Ownership distribution'
)
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Analysis from above
#
# - Primary Dominance: First Owners represent the clear majority at 61.2%, indicating a strong preference for original purchases.
#
# - Rapid Drop-off: While Second Owners hold a solid 28.5%, the market share collapses for subsequent owners; Third and Fourth+ owners combined make up barely 10%.
#
# - Negligible Assets: Test Drive Cars are statistically insignificant at just 0.1%, suggesting they are almost immediately transitioned to private ownership.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Barplot

# %% [markdown]
# ##### 1.Realation between fuel types affecting mileage

# %%
plt.figure(figsize=(5,3))
sns.barplot(data=df_new,x='fuel',y='mileage')
plt.title("fuel vs mileage")
plt.xlabel("mileage of vehicles")
plt.ylabel("Fuel type of vehicles")
plt.show()

# %% [markdown]
# ## Analysis from above
# - CNG vehicle is getting more mileage compared to others and lpg getting least
# - majority vehicles is getting average mileage above 17 kmpl
# - There is only small deviation between petrol,diesel and lpg.

# %% [markdown]
# #### 2. Relation between model of vehicles with asking price

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=df_new,x='model',y='asking_price')
plt.title("Average price of vehicles")
plt.xlabel("model of vehicles")
plt.ylabel("asking price")
plt.show()

# %% [markdown]
# ### Analysis from above
#
#
# - Resale value is directly propotional to model of the vehicle.latest model having resale value
# - In this graph we can see 1983 vehicles having resale value than 2010 because demand of the vintagecars and also because of some vintage vehicles fans
# - Average resale value of vehicles is high in the 2019 model and low at 2001 but 2020 some more outliers because luxury vehicles may increased its resale price and also budget vehicles is keep low comparitevely to 2019.
# - the resale value of vehicles  from 1994 to 2004 is almost keeping stable.
# - From 2013 there is a drastic change in the increasing of resale value of cars.

# %% [markdown]
# > Insights
# - Model affects resale value newest models having high resale value
# - Vintage vehicles also have medium resale value

# %% [markdown]
# 3. How does manual and automatic transimmision effecting asking price

# %%
plt.figure(figsize=(5,3))
sns.barplot(data=df_new,x='transmission',y='asking_price')
plt.title("Average price of vehicles")
plt.xlabel("Transmission type of vehicles")
plt.ylabel("asking price")
plt.show()

# %% [markdown]
# ### Analyses from above
#
# - Automatic transmission cars have a much higher average asking price than manual cars, suggesting transmission type is associated with car value.
#
# - Manual cars are generally priced lower, indicating they are more common in budget-friendly segments.
#
# - The wider error bar for automatic cars suggests greater price variation, meaning automatic vehicles appear across a broader range of price levels.

# %% [markdown]
# 4. how does seller type influencing asking price

# %%
plt.figure(figsize=(5,3))
sns.barplot(data=df_new,x='seller_type',y='asking_price')
plt.title("Average price of vehicles")
plt.xlabel("seller type of vehicles")
plt.ylabel("asking price")
plt.show()

# %% [markdown]
# ###  Analyses from above
#
# - Dealer-listed cars have the highest average asking price, suggesting dealers tend to sell more premium or higher-valued vehicles.
# - Individual sellers have the lowest average prices, indicating privately sold cars are generally more budget-friendly.
# - Trustmark Dealers show moderate prices with higher variation, while dealers appear to command consistently higher prices.

# %% [markdown]
# 5. How does ownership effecting resale value

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df_new,x='owner',y='asking_price')
plt.title("Average price of vehicles")
plt.xlabel("ownership of vehicles")
plt.ylabel("asking price")
plt.show()

# %% [markdown]
# #### Analysis from above
#
# - As ownership count increases, average asking price tends to decrease, indicating lower resale value for cars with multiple owners.
# - First-owner cars command higher prices than second, third, and fourth-owner cars, suggesting buyers value lower ownership history.
# - Test drive cars have the highest average price but show large price variation.

# %% [markdown]
# ## Line plot

# %% [markdown]
# #### Is mileage affect car selling price

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df_new,x='mileage',y='asking_price')
plt.title("Trend of vehicles price over mileage")
plt.xlabel("mileage")
plt.ylabel("price")
plt.show()

# %% [markdown]
# #### Analysis from the above graph

# %% [markdown]
# - mileage getting arround 9kmpl to 25kmpl show wide price variation,it indicating mileage alone doesn't determine price.
# - after 23kmpl to 35kmpl this category resale value is slightly lower because its this segments contains mainly CNG(cng segments is low price in resale)
# - after 35kmpl some vehicles has high in resale value maybe its also contains some performance based family car,luxury cars and its segment high mileage vehicles have demand in resale

# %% [markdown]
# > Insights

# %% [markdown]
# - There is no clear relathionship between mileage and price visible from this graph.

# %% [markdown]
# # Day 7

# %% [markdown]
# ## Scatter

# %% [markdown]
# ### Fuel type vs price
# Q.>Is fuel type affects car resale value??

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df_new,x='km_driven',y='asking_price')
plt.title("Trend of vehicles price over fuel type")
plt.xlabel("km_driven")
plt.ylabel("price")
plt.show()

# %% [markdown]
# #### Analysis from the above graph

# %% [markdown]
# - Vehicle price tends to decrease as kilometers driven increase, indicating cars with lower usage generally have higher market value.
# - Most vehicles are concentrated in lower kilometer ranges, with a wide spread in prices, suggesting km driven influences price but is not the only pricing factor.
# - A few high-kilometer outliers with unusual prices are present, which may represent nomalies or premium vehicles that retain value despite heavy usage.

# %% [markdown]
# # Multivariate analysis

# %%
df.describe()
# Out:
#              model  asking_price     km_driven      mileage       engine  \
# count  6926.000000  6.926000e+03  6.926000e+03  6926.000000  6926.000000
# mean   2013.420300  5.172707e+05  7.399568e+04    19.495554  1425.398787
# std       4.078286  5.197670e+05  5.835810e+04     3.888449   487.026967
# min    1983.000000  2.999900e+04  1.000000e+00     8.500000   624.000000
# 25%    2011.000000  2.500000e+05  4.000000e+04    16.960000  1197.000000
# 50%    2014.000000  4.000000e+05  7.000000e+04    19.300000  1248.000000
# 75%    2017.000000  6.335000e+05  1.000000e+05    22.320000  1498.000000
# max    2020.000000  1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power        seats
# count  6926.000000  6926.000000
# mean     87.556583     5.421600
# std      31.310612     0.972171
# min       0.000000     2.000000
# 25%      68.000000     5.000000
# 50%      81.860000     5.000000
# 75%      99.000000     5.000000
# max     400.000000    14.000000

# %% [markdown]
# ### Pair plot

# %% [markdown]
# Effect of Engine capacity and max power on car price

# %%
sns.pairplot(data=df_new[['engine','max_power','asking_price']])
plt.show()

# %% [markdown]
# > insights
# - Cars with both high engine CC and high max power tend to have much higher prices
# - smaller engine and high max power tend to to higher prices, showing power has a stronger influence.
# - large engine and low in max power tend to their prices are not as high as expected.
#
# > Analysis from above insight
# - Large engine alone doesn’t guarantee high price.max_power decides the price

# %% [markdown]
# # Heat map

# %%
plt.figure(figsize=(5,3))
numeric_cols=df_new.select_dtypes(include=['float64','int64']).corr()
sns.heatmap(numeric_cols,annot=True,cmap='coolwarm')
plt.title("correlation Heatmap")
plt.show()

# %% [markdown]
# ## Analyses from above

# %% [markdown]
# > Insights
#
# Power Premiums: High max_power is the strongest driver of asking_price (0.69), meaning performance dictates market value.
#
# Size & Scale: Engine displacement scales with both power (0.68) and seating capacity (0.66); larger vehicles consistently utilize bigger engines.
#
# Efficiency Tax: Mileage drops as engine size and seating increase (−0.59 and −0.48), highlighting a direct trade-off between utility and fuel economy.

# %% [markdown]
# ## Final Insights
#
# 1. Manufacturing Year vs. Price
# - The model (year) has a 0.43 positive correlation with asking_price. This confirms that as the manufacturing year increases (newer cars), the price also increases.
#
# 2. Fuel Type and Resale Value
# - Deisel vehicle have the highest average asking price comparitively to other fuel types.
# - LPG and CNG show shows comparitively lower average asking price
#
# 3. Transmission type effecting resale value
# - Automatic transmission cars have a much higher average asking price than manual cars, suggesting transmission type is associated with car value.
#
# 4. Seller Type Influencing resale value
# - Dealer-listed cars have the highest average asking price, suggesting dealers tend to sell more premium or higher-valued v ehicles.
# - Individual sellers have the lowest average prices, indicating privately sold cars are generally more budget-friendly.
# - Trustmark Dealers show moderate prices with higher variation, while dealers appear to command consistently higher prices.
#
# 5. Ownership influencing resale value
# - As ownership count increases, average asking price tends to decrease, indicating lower resale value for cars with multiple owners.
# - Test drive cars have the highest average price.It show large price variation.
#
# 6. Mileage effecting resale value
# - There is no clear relathionship between mileage and price visible from this data set.
#
# 7. Engine capacity(cc) impacting asking price
# - The engine cc has 0.44 positive correlation with asking price but not strong correlation.This confirms that as the engine capacity increases, the price also increases.
#
# 8. Max power and engine cc affect resale value
# -  Smaller engine and high max power tend to to higher prices, showing power has a stronger influence.Large engine alone doesn’t guarantee high price.max_power decides the price
#
# 9. Seats influencing selling price
# - The seat capacity has 0.16 positive correlation with asking price but weak correlation.This confirms that as the seat capacity has no clear impact in selling price
#
# 10. Depreciation trend
# - Depreciation appears influenced by age and usage together, with older,higher driven cars generally showing lower resale prices
